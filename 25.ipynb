# %%
#File Imports

from PythonFiles.trainer import trainer_function
from PythonFiles.tester import tester_function

# %load_ext autoreload
# %autoreload 2

# %%
#Tensorboard Extension for graphs
# %load_ext tensorboard
# %tensorboard --logdir logs --host localhost

#Hyperparameter Setting
hparams = {"batch_size" :32,
            "epochs":60,
            "droupout_p":0}

#Training 
trainer_function(hparams)
# Out:
#       <iframe id="tensorboard-frame-5e6cc53011482efe" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-5e6cc53011482efe");
#           const url = new URL("/", window.location);
#           url.port = 6010;
#           frame.src = url;
#         })();
#       </script>
# Data Initialisation Complete
# Train Data Loaded
# Validation Data Loaded
# Number of training samples: 6000
# Number of validation samples: 1000
# Using the  Device -  cuda:0
# Saved Log Name  logs/p0epoch60adadelta
# Started Training
# [Epoch 1] Training Loss 3.8937e-01  Validation Loss  3.9176e-02
# [Epoch 2] Training Loss 5.8023e-01  Validation Loss  5.7995e+01
# [Epoch 3] Training Loss 3.0363e-01  Validation Loss  1.6658e+00
# [Epoch 4] Training Loss 2.4414e-01  Validation Loss  1.0421e-02
# [Epoch 5] Training Loss 1.6891e-01  Validation Loss  3.5760e-03
# ...

# %%
#Testing with Sample Images
import numpy
rnd_idx=numpy.random.randint(0,98)
test_model_file_name="p=0epoch=60adadelta"
tester_function(rnd_idx,test_model_file_name)
# Out:
# Test Data Loaded
# Using the Following Device -  cuda:0
